# %% [markdown]
# ### Business Problem
#
# The market research team at a Fitness equipment comppany wants to identify the characteristics of the target audience for each type of treadmill offered by the company, to provide a better recommendation of the treadmills to the new customers. The team decides to investigate whether there are differences across the product with respect to customer characteristics. Perform descriptive analytics to  by developing appropriate tables and charts. For each  treadmill product, construct two-way contingency tables and compute all conditional and marginal probabilities along with their insights/impact on the business.

# %%
import pandas as pd 
import numpy  as np
import os

# %%
os.chdir(r"C:\Users\hp\Downloads")

# %%
df = pd.read_csv("aerofit_treadmill.csv")
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
#cheking null values

# %%
df.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %% [markdown]
# # probabilites

# %% [markdown]
# #Marginal Probabilities

# %%
#Probablility of getting a male customer buying

# %%
prob_Male=np.round(len(df[df["Gender"]=="Male"])/len(df),2)
prob_Male
# Out:
# 0.58

# %%
#Probablility of getting a Female customer buying

# %%
prob_Female=np.round(len(df[df["Gender"]=="Male"])/len(df),2)
prob_Female
# Out:
# 0.58

# %%
#Probablility of "single"  customer buying the product

# %%
prob_Single = np.round(len(df[df["MaritalStatus"]=="Single"])/len(df),2)
prob_Single
# Out:
# 0.41

# %%
#Probablility of "Partnered"  customer buying the product

# %%
prob_Partnered = np.round(len(df[df["MaritalStatus"]=="Partnered"])/len(df),2)
prob_Partnered
# Out:
# 0.59

# %% [markdown]
# ##Conditional Probability

# %%
#using Cross tab to get contengency table
#from the table we can find the conditonal probabities

# %%
table1=pd.crosstab(df.Product,df.Age[df.Age<30],normalize=True,margins=True)
table1
# Out:
# Age           18        19        20        21        22        23        24  \
# Product
# KP281    0.00885  0.026549  0.017699  0.035398  0.035398  0.070796  0.044248
# KP481    0.00000  0.008850  0.026549  0.026549  0.000000  0.061947  0.026549
# KP781    0.00000  0.000000  0.000000  0.000000  0.026549  0.026549  0.035398
# All      0.00885  0.035398  0.044248  0.061947  0.061947  0.159292  0.106195
#
# Age            25        26        27        28        29       All
# Product
# KP281    0.061947  0.061947  0.026549  0.053097  0.026549  0.469027
# KP481    0.097345  0.026549  0.008850  0.000000  0.008850  0.292035
# KP781    0.061947  0.017699  0.026549  0.026549  0.017699  0.238938
# All      0.221239  0.106195  0.061947  0.079646  0.053097  1.000000

# %%
#From the Table1 ,Probablity the customer buys a treadmill Given that the age of customer is between 
#(19 to 30) i.e Younger customers

# %%
KP281_given_youngercustomer=0.47

# %%
KP481_given_youngercustomer=0.29

# %%
KP781_given_youngercustomer=0.24

# %%
table2=pd.crosstab(df.Product,df.Age[df.Age>=30],normalize=True,margins=True)
table2
# Out:
# Age            30        31        32        33        34        35        36  \
# Product
# KP281    0.029851  0.029851  0.029851  0.029851  0.029851  0.044776  0.014925
# KP481    0.029851  0.044776  0.029851  0.074627  0.044776  0.059701  0.000000
# KP781    0.044776  0.014925  0.000000  0.014925  0.014925  0.014925  0.000000
# All      0.104478  0.089552  0.059701  0.119403  0.089552  0.119403  0.014925
#
# Age            37        38        39  ...        41        42        43  \
# Product                                ...
# KP281    0.014925  0.059701  0.014925  ...  0.014925  0.000000  0.014925
# KP481    0.014925  0.029851  0.000000  ...  0.000000  0.000000  0.000000
# KP781    0.000000  0.014925  0.000000  ...  0.000000  0.014925  0.000000
# All      0.029851  0.104478  0.014925  ...  0.014925  0.014925  0.014925
#
# Age            44        45        46        47        48        50       All
# Product
# ...

# %%
#From the Table2 ,Probablity the customer buys a treadmill Given that the age of customer is >30 
#i.e older age customers

# %%
KP281_given_oldercustomer=0.40

# %%
KP481_given_oldercustomer=0.40

# %%
KP781_given_oldercustomer=0.19

# %%
table3=pd.crosstab(df.Product,[df.MaritalStatus[df.MaritalStatus=="Partnered"],df.Usage],normalize=True,margins=True)
table3
# Out:
# MaritalStatus Partnered                                                    \
# Usage                 2         3         4         5         6         7
# Product
# KP281          0.112150  0.214953  0.112150  0.009346  0.000000  0.000000
# KP481          0.093458  0.158879  0.056075  0.028037  0.000000  0.000000
# KP781          0.000000  0.000000  0.102804  0.046729  0.046729  0.018692
# All            0.205607  0.373832  0.271028  0.084112  0.046729  0.018692
#
# MaritalStatus       All
# Usage
# Product
# KP281          0.448598
# KP481          0.336449
# KP781          0.214953
# All            1.000000

# %%
#From the Table3 ,Probablity the customer buys a treadmill Given that he/she is partnered

# %%
KP281_given_Partnered=0.44
KP481_given_Partnered=0.37
KP781_given_Partnered=0.21

# %%
table4=pd.crosstab(df.Product,[df.MaritalStatus[df.MaritalStatus=="Single"],df.Usage],normalize=True,margins=True)
table4
# Out:
# MaritalStatus    Single                                               All
# Usage                 2         3         4         5         6
# Product
# KP281          0.095890  0.191781  0.136986  0.013699  0.000000  0.438356
# KP481          0.054795  0.191781  0.082192  0.000000  0.000000  0.328767
# KP781          0.000000  0.013699  0.095890  0.095890  0.027397  0.232877
# All            0.150685  0.397260  0.315068  0.109589  0.027397  1.000000

# %%
#From the Table4 ,Probablity the customer buys a treadmill Given that he/she is single

# %%
KP281_given_Single=0.44
KP481_given_Single=0.33
KP781_given_Single=0.23

# %%
table5=pd.crosstab(df.Product,df.Gender[df.Gender=='Male'],normalize=True,margins=True)
table5
# Out:
# Gender       Male       All
# Product
# KP281    0.384615  0.384615
# KP481    0.298077  0.298077
# KP781    0.317308  0.317308
# All      1.000000  1.000000

# %%
#From the Table5 ,Probablity the male customer buys a specific treadmill

# %%
KP281_male=0.38
KP481_male=0.30
KP781_male=0.32

# %%
table6=pd.crosstab(df.Product,df.Gender[df.Gender=='Female'],normalize=True,margins=True)
table6
# Out:
# Gender     Female       All
# Product
# KP281    0.526316  0.526316
# KP481    0.381579  0.381579
# KP781    0.092105  0.092105
# All      1.000000  1.000000

# %%
#From the Table6 ,Probablity the female customer buys a specific treadmill

# %%
KP281_female=0.53
KP481_female=0.38
KP781_female=0.09

# %%
#Creating seperate dataframes based on model of treadmills

# %%
KP281=df[df["Product"]=="KP281"]
KP281.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %%
KP481=df[df["Product"]=="KP481"]
KP481.head()
# Out:
#    Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 80   KP481   19    Male         14        Single      3        3   31836
# 81   KP481   20    Male         14        Single      2        3   32973
# 82   KP481   20  Female         14     Partnered      3        3   34110
# 83   KP481   20    Male         14        Single      3        3   38658
# 84   KP481   21  Female         14     Partnered      5        4   34110
#
#     Miles
# 80     64
# 81     53
# 82    106
# 83     95
# 84    212

# %%
KP781=df[df["Product"]=="KP781"]
KP781.head()
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 140   KP781   22    Male         14        Single      4        3   48658
# 141   KP781   22    Male         16        Single      3        5   54781
# 142   KP781   22    Male         18        Single      4        5   48556
# 143   KP781   23    Male         16        Single      4        5   58516
# 144   KP781   23  Female         18        Single      5        4   53536
#
#      Miles
# 140    106
# 141    120
# 142    200
# 143    140
# 144    100

# %% [markdown]
# # Categorization of users

# %% [markdown]
# ##Univariate analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x = 'Product', data = df)
plt.title("Distribution of sales of Treadmills")
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.distplot(x= df['Usage'])
plt.title("Customer's expected Usage of Threadmill")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.histplot(df['MaritalStatus'])
plt.title("Distribution of Sales by Marital Status")
plt.show()

# %%
sns.histplot(y=df['Fitness'])
plt.title("Sales distribution over fitness")
plt.show()

# %% [markdown]
# ##Bivariate Analysis

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x= "Product",y= "Income",data = df)
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x= "Product",y= "Age",data = df)
plt.show()

# %% [markdown]
# ##Multivariate Anlaysis

# %%
sns.pairplot(data = df , hue= 'Product')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),cmap="Greens",annot=True)
plt.show()

# %% [markdown]
# ### Observations:
#
# 1.There are no missing values in the Data.
#
# 2.There are some outliers in the age column .

# %% [markdown]
# # Probabilities :
# 1.The Probabilities of Male and female customer buying the Product are same.
#
# 2.The probability of   "Partnered" customer buying the product is 0.18 more than the "Single " customer.
#
# 3.Probability that the customer buys a KP281 treadmill Given that the age of customer is between (19-29) is 0.47 which is almost double the probabilities of each other treadmills.
#
# 4.The probability of   customer aged more than 30 of buying a KP281 and KP 481 is same .i.e 0.4
#
# ### Univariate analysis :
# 1.Mostly expected usage of the product by the customer is seen to be average and near to below average.
#
# 2.Partnered  customers are more than the single customers
#
# 3.Average  fitness level customers are more frequent .
#
# ### Bivariate Analysis:
#
# 1.The income of Customers buying the KP281 and KP 481 are almost same.
#
# 2.The median income of customers buying KP781 is more than the highest income of customers buying KP281 and KP481.
#
# 3.The median age of customers for all three treadmills is in between 25 to 28.
#
# ### Multivariate Analysis:
# 1.From pair plot we can observe more density are between certain income and miles.
#
# 2.From the heat map it can be observed that there some negatively correlated columns.
#
# 3.High correlation is observed in between usage and miles  i.e 0.79 & miles and fitness 0.79.
#
# 4.Income and education are correlated with 0.63
#
# ### Recommendations:
# 1.Younger customers(19-29) are more likely to buy KP281 ,so we can recommend it to them.
#
# 2.We can recommend Older customers mostly KP281 or KP481 as the KP781 might seem too advanced for them.
#
# 3.KP281 and KP 481 can be recommended to customer whose income range is between 30k to 70 k dollars.
#
# 4.KP281 can be recommended  to customer whose Marital status is single.
#
# 5.KP281 and KP481 are most recommended for female customers
#
# 6.KP281 is suitable for customers for income above 60000$ and who uses the product quite often.
